# %%
data = '{"employee_name": "james", "email": "james@gmail.com", "job_profile": [{"title1": "Team Lead", "title2":"Sr.Developer"}]}'

# %%
data
# Out:
# '{"employee_name": "james", "email": "james@gmail.com", "job_profile": [{"title1": "Team Lead", "title2":"Sr.Developer"}]}'

# %%
type(data)
# Out:
# str

# %%
import pandas as pd

# %%
pd.read_json(data)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14328\1661395064.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_json(data)
#   employee_name            email  \
# 0         james  james@gmail.com
#
#                                          job_profile
# 0  {'title1': 'Team Lead', 'title2': 'Sr.Developer'}

# %%
pd.read_json(data,orient='records')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14328\2317705276.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_json(data,orient='records')
#   employee_name            email  \
# 0         james  james@gmail.com
#
#                                          job_profile
# 0  {'title1': 'Team Lead', 'title2': 'Sr.Developer'}

# %%
pd.read_json(data,orient='index')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14328\131370662.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_json(data,orient='index')
#                                                                0
# employee_name                                              james
# email                                            james@gmail.com
# job_profile    [{'title1': 'Team Lead', 'title2': 'Sr.Develop...

# %%
pd.read_json(data, orient='split')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14328\671204069.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_json(data, orient='split')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pd.read_json(data, orient='split')
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\json\_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# ...

# %%
pd.read_json(data, orient='columns')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14328\988300514.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_json(data, orient='columns')
#   employee_name            email  \
# 0         james  james@gmail.com
#
#                                          job_profile
# 0  {'title1': 'Team Lead', 'title2': 'Sr.Developer'}

# %%
df=pd.DataFrame([['a','b'],['c','d']],
                index=['row1','row2'],
                columns=['col 1','col 2'])

# %%
df
# Out:
#      col 1 col 2
# row1     a     b
# row2     c     d

# %%
## convert dataframe to json
df.to_json()
# Out:
# '{"col 1":{"row1":"a","row2":"c"},"col 2":{"row1":"b","row2":"d"}}'

# %%
df.to_json(orient='index')
# Out:
# '{"row1":{"col 1":"a","col 2":"b"},"row2":{"col 1":"c","col 2":"d"}}'

# %%
df.to_json(orient='columns')
# Out:
# '{"col 1":{"row1":"a","row2":"c"},"col 2":{"row1":"b","row2":"d"}}'

# %%
df.to_json(orient='records')
# Out:
# '[{"col 1":"a","col 2":"b"},{"col 1":"c","col 2":"d"}]'

# %%
df.to_json(orient='split')
# Out:
# '{"columns":["col 1","col 2"],"index":["row1","row2"],"data":[["a","b"],["c","d"]]}'

# %%
df.to_json(orient='table')
# Out:
# '{"schema":{"fields":[{"name":"index","type":"string"},{"name":"col 1","type":"string"},{"name":"col 2","type":"string"}],"primaryKey":["index"],"pandas_version":"1.4.0"},"data":[{"index":"row1","col 1":"a","col 2":"b"},{"index":"row2","col 1":"c","col 2":"d"}]}'

# %%
data = '{"schema":{"fields":[{"name":"index","type":"string"},{"name":"col 1","type":"string"},{"name":"col 2","type":"string"}],"primaryKey":["index"],"pandas_version":"1.4.0"},"data":[{"index":"row1","col 1":"a","col 2":"b"},{"index":"row2","col 1":"c","col 2":"d"}]}'

# %%
pd.read_json(data,orient='table')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14328\2076927000.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_json(data,orient='table')
#      col 1 col 2
# row1     a     b
# row2     c     d

# %%
df = pd.read_csv('mercedesbenz.csv',usecols=['ID','X0','X1','X2','X3','X4','X5','X6'])

# %%
df.head()
# Out:
#    ID  X0 X1  X2 X3 X4 X5 X6
# 0   0   k  v  at  a  d  u  j
# 1   6   k  t  av  e  d  y  l
# 2   7  az  w   n  c  d  x  j
# 3   9  az  t   n  f  d  x  l
# 4  13  az  v   n  f  d  h  d

# %%
df.to_json(orient='index')
# Out:
# '{"0":{"ID":0,"X0":"k","X1":"v","X2":"at","X3":"a","X4":"d","X5":"u","X6":"j"},"1":{"ID":6,"X0":"k","X1":"t","X2":"av","X3":"e","X4":"d","X5":"y","X6":"l"},"2":{"ID":7,"X0":"az","X1":"w","X2":"n","X3":"c","X4":"d","X5":"x","X6":"j"},"3":{"ID":9,"X0":"az","X1":"t","X2":"n","X3":"f","X4":"d","X5":"x","X6":"l"},"4":{"ID":13,"X0":"az","X1":"v","X2":"n","X3":"f","X4":"d","X5":"h","X6":"d"},"5":{"ID":18,"X0":"t","X1":"b","X2":"e","X3":"c","X4":"d","X5":"g","X6":"h"},"6":{"ID":24,"X0":"al","X1":"r","X2":"e","X3":"f","X4":"d","X5":"f","X6":"h"},"7":{"ID":25,"X0":"o","X1":"l","X2":"as","X3":"f","X4":"d","X5":"f","X6":"j"},"8":{"ID":27,"X0":"w","X1":"s","X2":"as","X3":"e","X4":"d","X5":"f","X6":"i"},"9":{"ID":30,"X0":"j","X1":"b","X2":"aq","X3":"c","X4":"d","X5":"f","X6":"a"},"10":{"ID":31,"X0":"h","X1":"r","X2":"r","X3":"f","X4":"d","X5":"f","X6":"h"},"11":{"ID":32,"X0":"al","X1":"r","X2":"e","X3":"f","X4":"d","X5":"f","X6":"h"},"12":{"ID":34,"X0":"s","X1":"b","X2":"ai","X3":"c","X4":"d","X5"
# ...

# %%
pd.read_json(data)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14328\1661395064.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_json(data)
#   employee_name            email  \
# 0         james  james@gmail.com
#
#                                          job_profile
# 0  {'title1': 'Team Lead', 'title2': 'Sr.Developer'}

# %%
data = [{"employee_name": "james", "email": "james@gmail.com", "job_profile": {"title1": "Team Lead", "title2":"Sr.Developer"}}] ## NESTED DICTIONARY

# %%
type(data)
# Out:
# list

# %%
pd.json_normalize(data)
# Out:
#   employee_name            email job_profile.title1 job_profile.title2
# 0         james  james@gmail.com          Team Lead       Sr.Developer

# %%
data = [
    {
        "id": 1,
        "name": "Cole Volk",
        "fitness": {"height": 130, "weight": 60},
    },
    {"name": "Mark Reg", 
     "fitness": {"height": 130, "weight": 60}},
    {
        "id": 2,
        "name": "Faye Raker",
        "fitness": {"height": 130, "weight": 60},
    },
]

# %%
pd.json_normalize(data)
# Out:
#     id        name  fitness.height  fitness.weight
# 0  1.0   Cole Volk             130              60
# 1  NaN    Mark Reg             130              60
# 2  2.0  Faye Raker             130              60

# %%
pd.json_normalize(data,max_level=0)
# Out:
#     id        name                        fitness
# 0  1.0   Cole Volk  {'height': 130, 'weight': 60}
# 1  NaN    Mark Reg  {'height': 130, 'weight': 60}
# 2  2.0  Faye Raker  {'height': 130, 'weight': 60}

# %%
pd.json_normalize(data,max_level=1)
# Out:
#     id        name  fitness.height  fitness.weight
# 0  1.0   Cole Volk             130              60
# 1  NaN    Mark Reg             130              60
# 2  2.0  Faye Raker             130              60

# %%
data = [
    {
        "state": "Florida",
        "shortname": "FL",
        "info": {"governor": "Rick Scott"},
        "counties": [
            {"name": "Dade", "population": 12345},
            {"name": "Broward", "population": 40000},
            {"name": "Palm Beach", "population": 60000},
        ],
    },
    {
        "state": "Ohio",
        "shortname": "OH",
        "info": {"governor": "John Kasich"},
        "counties": [
            {"name": "Summit", "population": 1234},
            {"name": "Cuyahoga", "population": 1337},
        ],
    },
]

# %%
pd.json_normalize(data)
# Out:
#      state shortname                                           counties  \
# 0  Florida        FL  [{'name': 'Dade', 'population': 12345}, {'name...
# 1     Ohio        OH  [{'name': 'Summit', 'population': 1234}, {'nam...
#
#   info.governor
# 0    Rick Scott
# 1   John Kasich

# %%
pd.json_normalize(data,max_level=0)
# Out:
#      state shortname                         info  \
# 0  Florida        FL   {'governor': 'Rick Scott'}
# 1     Ohio        OH  {'governor': 'John Kasich'}
#
#                                             counties
# 0  [{'name': 'Dade', 'population': 12345}, {'name...
# 1  [{'name': 'Summit', 'population': 1234}, {'nam...

# %%
pd.json_normalize(data,"counties")
# Out:
#          name  population
# 0        Dade       12345
# 1     Broward       40000
# 2  Palm Beach       60000
# 3      Summit        1234
# 4    Cuyahoga        1337

# %%
pd.json_normalize(data,"counties",["state","shortname"])
# Out:
#          name  population    state shortname
# 0        Dade       12345  Florida        FL
# 1     Broward       40000  Florida        FL
# 2  Palm Beach       60000  Florida        FL
# 3      Summit        1234     Ohio        OH
# 4    Cuyahoga        1337     Ohio        OH

# %%
pd.json_normalize(data,"counties",["state","shortname",["info",'governor']])
# Out:
#          name  population    state shortname info.governor
# 0        Dade       12345  Florida        FL    Rick Scott
# 1     Broward       40000  Florida        FL    Rick Scott
# 2  Palm Beach       60000  Florida        FL    Rick Scott
# 3      Summit        1234     Ohio        OH   John Kasich
# 4    Cuyahoga        1337     Ohio        OH   John Kasich
